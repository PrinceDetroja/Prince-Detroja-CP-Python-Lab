# %%
#Check if number is divisible by 10 or not
a=float(input("Enter a number: "))
if a%10==0:
    print(a,"is divisible by 10")
else:
    print(a,"is not divisible by 10")
# Out:
# Enter a number:  1234567890
# 1234567890.0 is divisible by 10
