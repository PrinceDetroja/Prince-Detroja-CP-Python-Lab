# %%
def name():
    s = set()
    for i in range(5):
        s.add(input("Enter a name: "))
    print(s)
    n_m = input("enter a name to modify: ")
    if n_m in s:
        newn_m = input("replace it with: ")
        s.remove(n_m)
        s.add(newn_m)
    else:
        print(n_m,"not found")
    print(s.pop(), " is deleted ")
    print(s.pop(), " is deleted ")
    print("The final list: ", s)
    
name()
# Out:
# Enter a name:  p
# Enter a name:  r
# Enter a name:  i
# Enter a name:  n
# Enter a name:  c
# {'c', 'n', 'r', 'i', 'p'}
# enter a name to modify:  p
# replace it with:  P
# c  is deleted
# P  is deleted
# The final list:  {'n', 'r', 'i'}
