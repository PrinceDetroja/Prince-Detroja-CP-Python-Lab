# %%
#Create a list of tuples containing a food item and its price. Sort the tuples in descending order by price.
def price():
    l=[(300,"Dosa"),(100,"Pav Bhaji"),(900,"Sizzler")]
    print(sorted(l,reverse=True))

price()
# Out:
# [(900, 'Sizzler'), (300, 'Dosa'), (100, 'Pav Bhaji')]

# %%
def price():
    l=[("Dosa",300),("Pav Bhaji",100),("Sizzler",900)]
    l1=[]
    a=0
    for i in l:
        for j in i:
            if isinstance(j, int):
                l1.append(j)
    l1.sort(reverse=True)
    print(l1)

price()
# Out:
# [900, 300, 100]
