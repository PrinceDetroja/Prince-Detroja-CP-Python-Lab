# %%
"""
A list contains tuples containg roll no., name and age of students. Write a python program to create 3 lists seperately for roll no., name and age.
"""
def separate():
    l=[("24BCP009","Prince",19),("24BCP011","Aryan",20),("24BCP021","Tirth",19),("24BCP022","Devarya",19)]
    l1=[l[0][0],l[1][0],l[2][0],l[3][0]]
    l2=[l[0][1],l[1][1],l[2][1],l[3][1]]
    l3=[l[0][2],l[1][2],l[2][2],l[3][2]]
    print("List of roll no. is:",l1)
    print("List of name is:",l2)
    print("List of age is:",l3)

separate()
# Out:
# List of roll no. is: ['24BCP009', '24BCP011', '24BCP021', '24BCP022']
# List of name is: ['Prince', 'Aryan', 'Tirth', 'Devarya']
# List of age is: [19, 20, 19, 19]
