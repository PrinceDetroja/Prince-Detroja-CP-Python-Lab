# %%
#Calculate area and perimeter of square
side=float(input('Enter side of square: '))
A=side**2
P=2*side
print('area od square=',A,'\n''Perimeter of square=',P)
# Out:
# Enter side of square:  4
# area od square= 16.0
# Perimeter of square= 8.0
