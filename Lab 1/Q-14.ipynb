# %%
#Convert celcius to fahrenhite F=(9/5*C+32)
C=float(input('Enter temperature in celcius: '))
F=(9/5*C+32)
print('temperature in fahrenhite=',F)
# Out:
# Enter temperature in celcius:  0
# temperature in fahrenhite= 32.0
