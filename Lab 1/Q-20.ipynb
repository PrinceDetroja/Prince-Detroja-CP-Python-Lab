# %%
#Area of triangle
H=float(input('Enter height of triangle: '))
L=float(input('Enter length of triangle: '))
A=H*L/2
print('Area of trianglr is=',A)
# Out:
# Enter height of triangle:  2
# Enter length of triangle:  2
# Area of trianglr is= 2.0
