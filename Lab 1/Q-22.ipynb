# %%
#Calculate net sales where net sales=gross sales -10% discount of gross sales
G=float(input('Enter gross sales: '))
N=G-(0.1*G)
print('Net sales=',N)
# Out:
# Enter gross sales:  100
# Net sales= 90.0
