# %%
#Calculate interest
P=float(input('Enter Principal Amount: '))
R=float(input('Enter Rate: '))
N=float(input('Enter Time Period(in yeras): '))
I=P*R*N/100
print('Interest=',I)
# Out:
# Enter Principal Amount:  100
# Enter Rate:  1
# Enter Time Period(in yeras):  1
# Interest= 1.0
