# %%
#Swap 2 values
a=float(input('Enter 1st number: '))
b=float(input('Enter 2nd number: '))
a,b=b,a
print('1st number is=',a,'2nd number is',b)
# Out:
# Enter 1st number:  2
# Enter 2nd number:  4
# 1st number is= 4.0 2nd number is 2.0
