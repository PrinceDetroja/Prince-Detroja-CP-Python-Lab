# %%
#Convert Fahrenhite to celcius
F=float(input('Enter temperature in fahrenhite: '))
C=5/9*(F-32)
print('temperature in celcius:',C)
# Out:
# Enter temperature in fahrenhite:  32
# temperature in celcius: 0.0
